# %%
from inception_indexer import *
load_network(True)

# %%
graph = tf.get_default_graph()
operations = graph.get_operations()

# %%
for operation in operations:
    print "Operation:",operation.name
    for k in operation.inputs:
        print operation.name,"Input ",k.name,k.get_shape()
    for k in operation.outputs:
        print operation.name,"Output ",k.name
    print "\n"
# Out:
# Operation: Placeholder
# Placeholder Output  Placeholder:0
#
#
# Operation: DecodePng
# DecodePng Input  Placeholder:0 TensorShape([])
# DecodePng Output  DecodePng:0
#
#
# Operation: DecodeJpeg/contents
# DecodeJpeg/contents Output  DecodeJpeg/contents:0
#
#
# Operation: DecodeJpeg
# DecodeJpeg Input  DecodeJpeg/contents:0 TensorShape([])
# DecodeJpeg Output  DecodeJpeg:0
#
#
# Operation: Cast
# Cast Input  DecodePng:0 TensorShape([Dimension(None), Dimension(None), Dimension(3)])
# Cast Output  Cast:0
#
#
# Operation: ExpandDims/dim
# ExpandDims/dim Output  ExpandDims/dim:0
#
#
# Operation: ExpandDims
# ExpandDims Input  Cast:0 TensorShape([Dimension(None), Dimension(None), Dimension(3)])
# ExpandDims Input  ExpandDims/dim:0 TensorShape([Dimension(1)])
# ExpandDims Output  ExpandDims:0
#
#
# Operation: ResizeBilinear/size
# ResizeBilinear/size Output  ResizeBilinear/size:0
#
#
# Operation: ResizeBilinear
# ResizeBilinear Input  ExpandDims:0 TensorShape([Dimension(1), Dimension(None), Dimension(None), Dimension(3)])
# ResizeBilinear Input  ResizeBilinear/size:0 TensorShape([Dimension(2)])
# ResizeBilinear Output  ResizeBilinear:0
#
#
# Operation: Sub/y
# Sub/y Output  Sub/y:0
#
#
# Operation: Sub
# Sub Input  ResizeBilinear:0 TensorShape([Dimension(1), Dimension(299), Dimension(299), Dimension(3)])
# Sub Input  Sub/y:0 TensorShape([])
# Sub Output  Sub:0
#
#
# Operation: Mul/y
# Mul/y Output  Mul/y:0
#
#
# Operation: Mul
# Mul Input  Sub:0 TensorShape([Dimension(1), Dimension(299), Dimension(299), Dimension(3)])
# Mul Input  Mul/y:0 TensorShape([])
# Mul Output  Mul:0
#
#
# Operation: conv/conv2d_params
# conv/conv2d_params Output  conv/conv2d_params:0
#
#
# Operation: conv/Conv2D
# conv/Conv2D Input  Mul:0 TensorShape([Dimension(1), Dimension(299), Dimension(299), Dimension(3)])
# conv/Conv2D Input  conv/conv2d_params:0 TensorShape([Dimension(3), Dimension(3), Dimension(3), Dimension(32)])
# conv/Conv2D Output  conv/Conv2D:0
#
#
# Operation: conv/batchnorm/beta
# conv/batchnorm/beta Output  conv/batchnorm/beta:0
#
#
# Operation: conv/batchnorm/gamma
# conv/batchnorm/gamma Output  conv/batchnorm/gamma:0
#
#
# Operation: conv/batchnorm/moving_mean
# conv/batchnorm/moving_mean Output  conv/batchnorm/moving_mean:0
#
#
# Operation: conv/batchnorm/moving_variance
# conv/batchnorm/moving_variance Output  conv/batchnorm/moving_variance:0
#
#
# Operation: conv/batchnorm
# conv/batchnorm Input  conv/Conv2D:0 TensorShape([Dimension(1), Dimension(149), Dimension(149), Dimension(32)])
# conv/batchnorm Input  conv/batchnorm/moving_mean:0 TensorShape([Dimension(32)])
# conv/batchnorm Input  conv/batchnorm/moving_variance:0 TensorShape([Dimension(32)])
# conv/batchnorm Input  conv/batchnorm/beta:0 TensorShape([Dimension(32)])
# conv/batchnorm Input  conv/batchnorm/gamma:0 TensorShape([Dimension(32)])
# conv/batchnorm Output  conv/batchnorm:0
#
#
# Operation: conv/CheckNumerics
# conv/CheckNumerics Input  conv/batchnorm:0 TensorShape([Dimension(1), Dimension(149), Dimension(149), Dimension(32)])
# conv/CheckNumerics Output  conv/CheckNumerics:0
#
#
# Operation: conv/control_dependency
# conv/control_dependency Input  conv/batchnorm:0 TensorShape([Dimension(1), Dimension(149), Dimension(149), Dimension(32)])
# conv/control_dependency Output  conv/control_dependency:0
#
#
# Operation: conv
# conv Input  conv/control_dependency:0 TensorShape([Dimension(1), Dimension(149), Dimension(149), Dimension(32)])
# conv Output  conv:0
#
#
# Operation: conv_1/conv2d_params
# conv_1/conv2d_params Output  conv_1/conv2d_params:0
#
#
# Operation: conv_1/Conv2D
# conv_1/Conv2D Input  conv:0 TensorShape([Dimension(1), Dimension(149), Dimension(149), Dimension(32)])
# conv_1/Conv2D Input  conv_1/conv2d_params:0 TensorShape([Dimension(3), Dimension(3), Dimension(32), Dimension(32)])
# conv_1/Conv2D Output  conv_1/Conv2D:0
#
#
# Operation: conv_1/batchnorm/beta
# conv_1/batchnorm/beta Output  conv_1/batchnorm/beta:0
#
#
# Operation: conv_1/batchnorm/gamma
# conv_1/batchnorm/gamma Output  conv_1/batchnorm/gamma:0
#
#
# Operation: conv_1/batchnorm/moving_mean
# conv_1/batchnorm/moving_mean Output  conv_1/batchnorm/moving_mean:0
#
#
# Operation: conv_1/batchnorm/moving_variance
# conv_1/batchnorm/moving_variance Output  conv_1/batchnorm/moving_variance:0
#
#
# Operation: conv_1/batchnorm
# conv_1/batchnorm Input  conv_1/Conv2D:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(32)])
# conv_1/batchnorm Input  conv_1/batchnorm/moving_mean:0 TensorShape([Dimension(32)])
# conv_1/batchnorm Input  conv_1/batchnorm/moving_variance:0 TensorShape([Dimension(32)])
# conv_1/batchnorm Input  conv_1/batchnorm/beta:0 TensorShape([Dimension(32)])
# conv_1/batchnorm Input  conv_1/batchnorm/gamma:0 TensorShape([Dimension(32)])
# conv_1/batchnorm Output  conv_1/batchnorm:0
#
#
# Operation: conv_1/CheckNumerics
# conv_1/CheckNumerics Input  conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(32)])
# conv_1/CheckNumerics Output  conv_1/CheckNumerics:0
#
#
# Operation: conv_1/control_dependency
# conv_1/control_dependency Input  conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(32)])
# conv_1/control_dependency Output  conv_1/control_dependency:0
#
#
# Operation: conv_1
# conv_1 Input  conv_1/control_dependency:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(32)])
# conv_1 Output  conv_1:0
#
#
# Operation: conv_2/conv2d_params
# conv_2/conv2d_params Output  conv_2/conv2d_params:0
#
#
# Operation: conv_2/Conv2D
# conv_2/Conv2D Input  conv_1:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(32)])
# conv_2/Conv2D Input  conv_2/conv2d_params:0 TensorShape([Dimension(3), Dimension(3), Dimension(32), Dimension(64)])
# conv_2/Conv2D Output  conv_2/Conv2D:0
#
#
# Operation: conv_2/batchnorm/beta
# conv_2/batchnorm/beta Output  conv_2/batchnorm/beta:0
#
#
# Operation: conv_2/batchnorm/gamma
# conv_2/batchnorm/gamma Output  conv_2/batchnorm/gamma:0
#
#
# Operation: conv_2/batchnorm/moving_mean
# conv_2/batchnorm/moving_mean Output  conv_2/batchnorm/moving_mean:0
#
#
# Operation: conv_2/batchnorm/moving_variance
# conv_2/batchnorm/moving_variance Output  conv_2/batchnorm/moving_variance:0
#
#
# Operation: conv_2/batchnorm
# conv_2/batchnorm Input  conv_2/Conv2D:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(64)])
# conv_2/batchnorm Input  conv_2/batchnorm/moving_mean:0 TensorShape([Dimension(64)])
# conv_2/batchnorm Input  conv_2/batchnorm/moving_variance:0 TensorShape([Dimension(64)])
# conv_2/batchnorm Input  conv_2/batchnorm/beta:0 TensorShape([Dimension(64)])
# conv_2/batchnorm Input  conv_2/batchnorm/gamma:0 TensorShape([Dimension(64)])
# conv_2/batchnorm Output  conv_2/batchnorm:0
#
#
# Operation: conv_2/CheckNumerics
# conv_2/CheckNumerics Input  conv_2/batchnorm:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(64)])
# conv_2/CheckNumerics Output  conv_2/CheckNumerics:0
#
#
# Operation: conv_2/control_dependency
# conv_2/control_dependency Input  conv_2/batchnorm:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(64)])
# conv_2/control_dependency Output  conv_2/control_dependency:0
#
#
# Operation: conv_2
# conv_2 Input  conv_2/control_dependency:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(64)])
# conv_2 Output  conv_2:0
#
#
# Operation: pool/CheckNumerics
# pool/CheckNumerics Input  conv_2:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(64)])
# pool/CheckNumerics Output  pool/CheckNumerics:0
#
#
# Operation: pool/control_dependency
# pool/control_dependency Input  conv_2:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(64)])
# pool/control_dependency Output  pool/control_dependency:0
#
#
# Operation: pool
# pool Input  pool/control_dependency:0 TensorShape([Dimension(1), Dimension(147), Dimension(147), Dimension(64)])
# pool Output  pool:0
#
#
# Operation: conv_3/conv2d_params
# conv_3/conv2d_params Output  conv_3/conv2d_params:0
#
#
# Operation: conv_3/Conv2D
# conv_3/Conv2D Input  pool:0 TensorShape([Dimension(1), Dimension(73), Dimension(73), Dimension(64)])
# conv_3/Conv2D Input  conv_3/conv2d_params:0 TensorShape([Dimension(1), Dimension(1), Dimension(64), Dimension(80)])
# conv_3/Conv2D Output  conv_3/Conv2D:0
#
#
# Operation: conv_3/batchnorm/beta
# conv_3/batchnorm/beta Output  conv_3/batchnorm/beta:0
#
#
# Operation: conv_3/batchnorm/gamma
# conv_3/batchnorm/gamma Output  conv_3/batchnorm/gamma:0
#
#
# Operation: conv_3/batchnorm/moving_mean
# conv_3/batchnorm/moving_mean Output  conv_3/batchnorm/moving_mean:0
#
#
# Operation: conv_3/batchnorm/moving_variance
# conv_3/batchnorm/moving_variance Output  conv_3/batchnorm/moving_variance:0
#
#
# Operation: conv_3/batchnorm
# conv_3/batchnorm Input  conv_3/Conv2D:0 TensorShape([Dimension(1), Dimension(73), Dimension(73), Dimension(80)])
# conv_3/batchnorm Input  conv_3/batchnorm/moving_mean:0 TensorShape([Dimension(80)])
# conv_3/batchnorm Input  conv_3/batchnorm/moving_variance:0 TensorShape([Dimension(80)])
# conv_3/batchnorm Input  conv_3/batchnorm/beta:0 TensorShape([Dimension(80)])
# conv_3/batchnorm Input  conv_3/batchnorm/gamma:0 TensorShape([Dimension(80)])
# conv_3/batchnorm Output  conv_3/batchnorm:0
#
#
# Operation: conv_3/CheckNumerics
# conv_3/CheckNumerics Input  conv_3/batchnorm:0 TensorShape([Dimension(1), Dimension(73), Dimension(73), Dimension(80)])
# conv_3/CheckNumerics Output  conv_3/CheckNumerics:0
#
#
# Operation: conv_3/control_dependency
# conv_3/control_dependency Input  conv_3/batchnorm:0 TensorShape([Dimension(1), Dimension(73), Dimension(73), Dimension(80)])
# conv_3/control_dependency Output  conv_3/control_dependency:0
#
#
# Operation: conv_3
# conv_3 Input  conv_3/control_dependency:0 TensorShape([Dimension(1), Dimension(73), Dimension(73), Dimension(80)])
# conv_3 Output  conv_3:0
#
#
# Operation: conv_4/conv2d_params
# conv_4/conv2d_params Output  conv_4/conv2d_params:0
#
#
# Operation: conv_4/Conv2D
# conv_4/Conv2D Input  conv_3:0 TensorShape([Dimension(1), Dimension(73), Dimension(73), Dimension(80)])
# conv_4/Conv2D Input  conv_4/conv2d_params:0 TensorShape([Dimension(3), Dimension(3), Dimension(80), Dimension(192)])
# conv_4/Conv2D Output  conv_4/Conv2D:0
#
#
# Operation: conv_4/batchnorm/beta
# conv_4/batchnorm/beta Output  conv_4/batchnorm/beta:0
#
#
# Operation: conv_4/batchnorm/gamma
# conv_4/batchnorm/gamma Output  conv_4/batchnorm/gamma:0
#
#
# Operation: conv_4/batchnorm/moving_mean
# conv_4/batchnorm/moving_mean Output  conv_4/batchnorm/moving_mean:0
#
#
# Operation: conv_4/batchnorm/moving_variance
# conv_4/batchnorm/moving_variance Output  conv_4/batchnorm/moving_variance:0
#
#
# Operation: conv_4/batchnorm
# conv_4/batchnorm Input  conv_4/Conv2D:0 TensorShape([Dimension(1), Dimension(71), Dimension(71), Dimension(192)])
# conv_4/batchnorm Input  conv_4/batchnorm/moving_mean:0 TensorShape([Dimension(192)])
# conv_4/batchnorm Input  conv_4/batchnorm/moving_variance:0 TensorShape([Dimension(192)])
# conv_4/batchnorm Input  conv_4/batchnorm/beta:0 TensorShape([Dimension(192)])
# conv_4/batchnorm Input  conv_4/batchnorm/gamma:0 TensorShape([Dimension(192)])
# conv_4/batchnorm Output  conv_4/batchnorm:0
#
#
# Operation: conv_4/CheckNumerics
# conv_4/CheckNumerics Input  conv_4/batchnorm:0 TensorShape([Dimension(1), Dimension(71), Dimension(71), Dimension(192)])
# conv_4/CheckNumerics Output  conv_4/CheckNumerics:0
#
#
# Operation: conv_4/control_dependency
# conv_4/control_dependency Input  conv_4/batchnorm:0 TensorShape([Dimension(1), Dimension(71), Dimension(71), Dimension(192)])
# conv_4/control_dependency Output  conv_4/control_dependency:0
#
#
# Operation: conv_4
# conv_4 Input  conv_4/control_dependency:0 TensorShape([Dimension(1), Dimension(71), Dimension(71), Dimension(192)])
# conv_4 Output  conv_4:0
#
#
# Operation: pool_1/CheckNumerics
# pool_1/CheckNumerics Input  conv_4:0 TensorShape([Dimension(1), Dimension(71), Dimension(71), Dimension(192)])
# pool_1/CheckNumerics Output  pool_1/CheckNumerics:0
#
#
# Operation: pool_1/control_dependency
# pool_1/control_dependency Input  conv_4:0 TensorShape([Dimension(1), Dimension(71), Dimension(71), Dimension(192)])
# pool_1/control_dependency Output  pool_1/control_dependency:0
#
#
# Operation: pool_1
# pool_1 Input  pool_1/control_dependency:0 TensorShape([Dimension(1), Dimension(71), Dimension(71), Dimension(192)])
# pool_1 Output  pool_1:0
#
#
# Operation: mixed/conv/conv2d_params
# mixed/conv/conv2d_params Output  mixed/conv/conv2d_params:0
#
#
# Operation: mixed/conv/Conv2D
# mixed/conv/Conv2D Input  pool_1:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(192)])
# mixed/conv/Conv2D Input  mixed/conv/conv2d_params:0 TensorShape([Dimension(1), Dimension(1), Dimension(192), Dimension(64)])
# mixed/conv/Conv2D Output  mixed/conv/Conv2D:0
#
#
# Operation: mixed/conv/batchnorm/beta
# mixed/conv/batchnorm/beta Output  mixed/conv/batchnorm/beta:0
#
#
# Operation: mixed/conv/batchnorm/gamma
# mixed/conv/batchnorm/gamma Output  mixed/conv/batchnorm/gamma:0
#
#
# Operation: mixed/conv/batchnorm/moving_mean
# mixed/conv/batchnorm/moving_mean Output  mixed/conv/batchnorm/moving_mean:0
#
#
# Operation: mixed/conv/batchnorm/moving_variance
# mixed/conv/batchnorm/moving_variance Output  mixed/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed/conv/batchnorm
# mixed/conv/batchnorm Input  mixed/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/conv/batchnorm Input  mixed/conv/batchnorm/moving_mean:0 TensorShape([Dimension(64)])
# mixed/conv/batchnorm Input  mixed/conv/batchnorm/moving_variance:0 TensorShape([Dimension(64)])
# mixed/conv/batchnorm Input  mixed/conv/batchnorm/beta:0 TensorShape([Dimension(64)])
# mixed/conv/batchnorm Input  mixed/conv/batchnorm/gamma:0 TensorShape([Dimension(64)])
# mixed/conv/batchnorm Output  mixed/conv/batchnorm:0
#
#
# Operation: mixed/conv/CheckNumerics
# mixed/conv/CheckNumerics Input  mixed/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/conv/CheckNumerics Output  mixed/conv/CheckNumerics:0
#
#
# Operation: mixed/conv/control_dependency
# mixed/conv/control_dependency Input  mixed/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/conv/control_dependency Output  mixed/conv/control_dependency:0
#
#
# Operation: mixed/conv
# mixed/conv Input  mixed/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/conv Output  mixed/conv:0
#
#
# Operation: mixed/tower/conv/conv2d_params
# mixed/tower/conv/conv2d_params Output  mixed/tower/conv/conv2d_params:0
#
#
# Operation: mixed/tower/conv/Conv2D
# mixed/tower/conv/Conv2D Input  pool_1:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(192)])
# mixed/tower/conv/Conv2D Input  mixed/tower/conv/conv2d_params:0 TensorShape([Dimension(1), Dimension(1), Dimension(192), Dimension(48)])
# mixed/tower/conv/Conv2D Output  mixed/tower/conv/Conv2D:0
#
#
# Operation: mixed/tower/conv/batchnorm/beta
# mixed/tower/conv/batchnorm/beta Output  mixed/tower/conv/batchnorm/beta:0
#
#
# Operation: mixed/tower/conv/batchnorm/gamma
# mixed/tower/conv/batchnorm/gamma Output  mixed/tower/conv/batchnorm/gamma:0
#
#
# Operation: mixed/tower/conv/batchnorm/moving_mean
# mixed/tower/conv/batchnorm/moving_mean Output  mixed/tower/conv/batchnorm/moving_mean:0
#
#
# Operation: mixed/tower/conv/batchnorm/moving_variance
# mixed/tower/conv/batchnorm/moving_variance Output  mixed/tower/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed/tower/conv/batchnorm
# mixed/tower/conv/batchnorm Input  mixed/tower/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(48)])
# mixed/tower/conv/batchnorm Input  mixed/tower/conv/batchnorm/moving_mean:0 TensorShape([Dimension(48)])
# mixed/tower/conv/batchnorm Input  mixed/tower/conv/batchnorm/moving_variance:0 TensorShape([Dimension(48)])
# mixed/tower/conv/batchnorm Input  mixed/tower/conv/batchnorm/beta:0 TensorShape([Dimension(48)])
# mixed/tower/conv/batchnorm Input  mixed/tower/conv/batchnorm/gamma:0 TensorShape([Dimension(48)])
# mixed/tower/conv/batchnorm Output  mixed/tower/conv/batchnorm:0
#
#
# Operation: mixed/tower/conv/CheckNumerics
# mixed/tower/conv/CheckNumerics Input  mixed/tower/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(48)])
# mixed/tower/conv/CheckNumerics Output  mixed/tower/conv/CheckNumerics:0
#
#
# Operation: mixed/tower/conv/control_dependency
# mixed/tower/conv/control_dependency Input  mixed/tower/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(48)])
# mixed/tower/conv/control_dependency Output  mixed/tower/conv/control_dependency:0
#
#
# Operation: mixed/tower/conv
# mixed/tower/conv Input  mixed/tower/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(48)])
# mixed/tower/conv Output  mixed/tower/conv:0
#
#
# Operation: mixed/tower/conv_1/conv2d_params
# mixed/tower/conv_1/conv2d_params Output  mixed/tower/conv_1/conv2d_params:0
#
#
# Operation: mixed/tower/conv_1/Conv2D
# mixed/tower/conv_1/Conv2D Input  mixed/tower/conv:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(48)])
# mixed/tower/conv_1/Conv2D Input  mixed/tower/conv_1/conv2d_params:0 TensorShape([Dimension(5), Dimension(5), Dimension(48), Dimension(64)])
# mixed/tower/conv_1/Conv2D Output  mixed/tower/conv_1/Conv2D:0
#
#
# Operation: mixed/tower/conv_1/batchnorm/beta
# mixed/tower/conv_1/batchnorm/beta Output  mixed/tower/conv_1/batchnorm/beta:0
#
#
# Operation: mixed/tower/conv_1/batchnorm/gamma
# mixed/tower/conv_1/batchnorm/gamma Output  mixed/tower/conv_1/batchnorm/gamma:0
#
#
# Operation: mixed/tower/conv_1/batchnorm/moving_mean
# mixed/tower/conv_1/batchnorm/moving_mean Output  mixed/tower/conv_1/batchnorm/moving_mean:0
#
#
# Operation: mixed/tower/conv_1/batchnorm/moving_variance
# mixed/tower/conv_1/batchnorm/moving_variance Output  mixed/tower/conv_1/batchnorm/moving_variance:0
#
#
# Operation: mixed/tower/conv_1/batchnorm
# mixed/tower/conv_1/batchnorm Input  mixed/tower/conv_1/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/tower/conv_1/batchnorm Input  mixed/tower/conv_1/batchnorm/moving_mean:0 TensorShape([Dimension(64)])
# mixed/tower/conv_1/batchnorm Input  mixed/tower/conv_1/batchnorm/moving_variance:0 TensorShape([Dimension(64)])
# mixed/tower/conv_1/batchnorm Input  mixed/tower/conv_1/batchnorm/beta:0 TensorShape([Dimension(64)])
# mixed/tower/conv_1/batchnorm Input  mixed/tower/conv_1/batchnorm/gamma:0 TensorShape([Dimension(64)])
# mixed/tower/conv_1/batchnorm Output  mixed/tower/conv_1/batchnorm:0
#
#
# Operation: mixed/tower/conv_1/CheckNumerics
# mixed/tower/conv_1/CheckNumerics Input  mixed/tower/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/tower/conv_1/CheckNumerics Output  mixed/tower/conv_1/CheckNumerics:0
#
#
# Operation: mixed/tower/conv_1/control_dependency
# mixed/tower/conv_1/control_dependency Input  mixed/tower/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/tower/conv_1/control_dependency Output  mixed/tower/conv_1/control_dependency:0
#
#
# Operation: mixed/tower/conv_1
# mixed/tower/conv_1 Input  mixed/tower/conv_1/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/tower/conv_1 Output  mixed/tower/conv_1:0
#
#
# Operation: mixed/tower_1/conv/conv2d_params
# mixed/tower_1/conv/conv2d_params Output  mixed/tower_1/conv/conv2d_params:0
#
#
# Operation: mixed/tower_1/conv/Conv2D
# mixed/tower_1/conv/Conv2D Input  pool_1:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(192)])
# mixed/tower_1/conv/Conv2D Input  mixed/tower_1/conv/conv2d_params:0 TensorShape([Dimension(1), Dimension(1), Dimension(192), Dimension(64)])
# mixed/tower_1/conv/Conv2D Output  mixed/tower_1/conv/Conv2D:0
#
#
# Operation: mixed/tower_1/conv/batchnorm/beta
# mixed/tower_1/conv/batchnorm/beta Output  mixed/tower_1/conv/batchnorm/beta:0
#
#
# Operation: mixed/tower_1/conv/batchnorm/gamma
# mixed/tower_1/conv/batchnorm/gamma Output  mixed/tower_1/conv/batchnorm/gamma:0
#
#
# Operation: mixed/tower_1/conv/batchnorm/moving_mean
# mixed/tower_1/conv/batchnorm/moving_mean Output  mixed/tower_1/conv/batchnorm/moving_mean:0
#
#
# Operation: mixed/tower_1/conv/batchnorm/moving_variance
# mixed/tower_1/conv/batchnorm/moving_variance Output  mixed/tower_1/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed/tower_1/conv/batchnorm
# mixed/tower_1/conv/batchnorm Input  mixed/tower_1/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/tower_1/conv/batchnorm Input  mixed/tower_1/conv/batchnorm/moving_mean:0 TensorShape([Dimension(64)])
# mixed/tower_1/conv/batchnorm Input  mixed/tower_1/conv/batchnorm/moving_variance:0 TensorShape([Dimension(64)])
# mixed/tower_1/conv/batchnorm Input  mixed/tower_1/conv/batchnorm/beta:0 TensorShape([Dimension(64)])
# mixed/tower_1/conv/batchnorm Input  mixed/tower_1/conv/batchnorm/gamma:0 TensorShape([Dimension(64)])
# mixed/tower_1/conv/batchnorm Output  mixed/tower_1/conv/batchnorm:0
#
#
# Operation: mixed/tower_1/conv/CheckNumerics
# mixed/tower_1/conv/CheckNumerics Input  mixed/tower_1/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/tower_1/conv/CheckNumerics Output  mixed/tower_1/conv/CheckNumerics:0
#
#
# Operation: mixed/tower_1/conv/control_dependency
# mixed/tower_1/conv/control_dependency Input  mixed/tower_1/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/tower_1/conv/control_dependency Output  mixed/tower_1/conv/control_dependency:0
#
#
# Operation: mixed/tower_1/conv
# mixed/tower_1/conv Input  mixed/tower_1/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/tower_1/conv Output  mixed/tower_1/conv:0
#
#
# Operation: mixed/tower_1/conv_1/conv2d_params
# mixed/tower_1/conv_1/conv2d_params Output  mixed/tower_1/conv_1/conv2d_params:0
#
#
# Operation: mixed/tower_1/conv_1/Conv2D
# mixed/tower_1/conv_1/Conv2D Input  mixed/tower_1/conv:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/tower_1/conv_1/Conv2D Input  mixed/tower_1/conv_1/conv2d_params:0 TensorShape([Dimension(3), Dimension(3), Dimension(64), Dimension(96)])
# mixed/tower_1/conv_1/Conv2D Output  mixed/tower_1/conv_1/Conv2D:0
#
#
# Operation: mixed/tower_1/conv_1/batchnorm/beta
# mixed/tower_1/conv_1/batchnorm/beta Output  mixed/tower_1/conv_1/batchnorm/beta:0
#
#
# Operation: mixed/tower_1/conv_1/batchnorm/gamma
# mixed/tower_1/conv_1/batchnorm/gamma Output  mixed/tower_1/conv_1/batchnorm/gamma:0
#
#
# Operation: mixed/tower_1/conv_1/batchnorm/moving_mean
# mixed/tower_1/conv_1/batchnorm/moving_mean Output  mixed/tower_1/conv_1/batchnorm/moving_mean:0
#
#
# Operation: mixed/tower_1/conv_1/batchnorm/moving_variance
# mixed/tower_1/conv_1/batchnorm/moving_variance Output  mixed/tower_1/conv_1/batchnorm/moving_variance:0
#
#
# Operation: mixed/tower_1/conv_1/batchnorm
# mixed/tower_1/conv_1/batchnorm Input  mixed/tower_1/conv_1/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed/tower_1/conv_1/batchnorm Input  mixed/tower_1/conv_1/batchnorm/moving_mean:0 TensorShape([Dimension(96)])
# mixed/tower_1/conv_1/batchnorm Input  mixed/tower_1/conv_1/batchnorm/moving_variance:0 TensorShape([Dimension(96)])
# mixed/tower_1/conv_1/batchnorm Input  mixed/tower_1/conv_1/batchnorm/beta:0 TensorShape([Dimension(96)])
# mixed/tower_1/conv_1/batchnorm Input  mixed/tower_1/conv_1/batchnorm/gamma:0 TensorShape([Dimension(96)])
# mixed/tower_1/conv_1/batchnorm Output  mixed/tower_1/conv_1/batchnorm:0
#
#
# Operation: mixed/tower_1/conv_1/CheckNumerics
# mixed/tower_1/conv_1/CheckNumerics Input  mixed/tower_1/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed/tower_1/conv_1/CheckNumerics Output  mixed/tower_1/conv_1/CheckNumerics:0
#
#
# Operation: mixed/tower_1/conv_1/control_dependency
# mixed/tower_1/conv_1/control_dependency Input  mixed/tower_1/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed/tower_1/conv_1/control_dependency Output  mixed/tower_1/conv_1/control_dependency:0
#
#
# Operation: mixed/tower_1/conv_1
# mixed/tower_1/conv_1 Input  mixed/tower_1/conv_1/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed/tower_1/conv_1 Output  mixed/tower_1/conv_1:0
#
#
# Operation: mixed/tower_1/conv_2/conv2d_params
# mixed/tower_1/conv_2/conv2d_params Output  mixed/tower_1/conv_2/conv2d_params:0
#
#
# Operation: mixed/tower_1/conv_2/Conv2D
# mixed/tower_1/conv_2/Conv2D Input  mixed/tower_1/conv_1:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed/tower_1/conv_2/Conv2D Input  mixed/tower_1/conv_2/conv2d_params:0 TensorShape([Dimension(3), Dimension(3), Dimension(96), Dimension(96)])
# mixed/tower_1/conv_2/Conv2D Output  mixed/tower_1/conv_2/Conv2D:0
#
#
# Operation: mixed/tower_1/conv_2/batchnorm/beta
# mixed/tower_1/conv_2/batchnorm/beta Output  mixed/tower_1/conv_2/batchnorm/beta:0
#
#
# Operation: mixed/tower_1/conv_2/batchnorm/gamma
# mixed/tower_1/conv_2/batchnorm/gamma Output  mixed/tower_1/conv_2/batchnorm/gamma:0
#
#
# Operation: mixed/tower_1/conv_2/batchnorm/moving_mean
# mixed/tower_1/conv_2/batchnorm/moving_mean Output  mixed/tower_1/conv_2/batchnorm/moving_mean:0
#
#
# Operation: mixed/tower_1/conv_2/batchnorm/moving_variance
# mixed/tower_1/conv_2/batchnorm/moving_variance Output  mixed/tower_1/conv_2/batchnorm/moving_variance:0
#
#
# Operation: mixed/tower_1/conv_2/batchnorm
# mixed/tower_1/conv_2/batchnorm Input  mixed/tower_1/conv_2/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed/tower_1/conv_2/batchnorm Input  mixed/tower_1/conv_2/batchnorm/moving_mean:0 TensorShape([Dimension(96)])
# mixed/tower_1/conv_2/batchnorm Input  mixed/tower_1/conv_2/batchnorm/moving_variance:0 TensorShape([Dimension(96)])
# mixed/tower_1/conv_2/batchnorm Input  mixed/tower_1/conv_2/batchnorm/beta:0 TensorShape([Dimension(96)])
# mixed/tower_1/conv_2/batchnorm Input  mixed/tower_1/conv_2/batchnorm/gamma:0 TensorShape([Dimension(96)])
# mixed/tower_1/conv_2/batchnorm Output  mixed/tower_1/conv_2/batchnorm:0
#
#
# Operation: mixed/tower_1/conv_2/CheckNumerics
# mixed/tower_1/conv_2/CheckNumerics Input  mixed/tower_1/conv_2/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed/tower_1/conv_2/CheckNumerics Output  mixed/tower_1/conv_2/CheckNumerics:0
#
#
# Operation: mixed/tower_1/conv_2/control_dependency
# mixed/tower_1/conv_2/control_dependency Input  mixed/tower_1/conv_2/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed/tower_1/conv_2/control_dependency Output  mixed/tower_1/conv_2/control_dependency:0
#
#
# Operation: mixed/tower_1/conv_2
# mixed/tower_1/conv_2 Input  mixed/tower_1/conv_2/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed/tower_1/conv_2 Output  mixed/tower_1/conv_2:0
#
#
# Operation: mixed/tower_2/pool
# mixed/tower_2/pool Input  pool_1:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(192)])
# mixed/tower_2/pool Output  mixed/tower_2/pool:0
#
#
# Operation: mixed/tower_2/conv/conv2d_params
# mixed/tower_2/conv/conv2d_params Output  mixed/tower_2/conv/conv2d_params:0
#
#
# Operation: mixed/tower_2/conv/Conv2D
# mixed/tower_2/conv/Conv2D Input  mixed/tower_2/pool:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(192)])
# mixed/tower_2/conv/Conv2D Input  mixed/tower_2/conv/conv2d_params:0 TensorShape([Dimension(1), Dimension(1), Dimension(192), Dimension(32)])
# mixed/tower_2/conv/Conv2D Output  mixed/tower_2/conv/Conv2D:0
#
#
# Operation: mixed/tower_2/conv/batchnorm/beta
# mixed/tower_2/conv/batchnorm/beta Output  mixed/tower_2/conv/batchnorm/beta:0
#
#
# Operation: mixed/tower_2/conv/batchnorm/gamma
# mixed/tower_2/conv/batchnorm/gamma Output  mixed/tower_2/conv/batchnorm/gamma:0
#
#
# Operation: mixed/tower_2/conv/batchnorm/moving_mean
# mixed/tower_2/conv/batchnorm/moving_mean Output  mixed/tower_2/conv/batchnorm/moving_mean:0
#
#
# Operation: mixed/tower_2/conv/batchnorm/moving_variance
# mixed/tower_2/conv/batchnorm/moving_variance Output  mixed/tower_2/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed/tower_2/conv/batchnorm
# mixed/tower_2/conv/batchnorm Input  mixed/tower_2/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(32)])
# mixed/tower_2/conv/batchnorm Input  mixed/tower_2/conv/batchnorm/moving_mean:0 TensorShape([Dimension(32)])
# mixed/tower_2/conv/batchnorm Input  mixed/tower_2/conv/batchnorm/moving_variance:0 TensorShape([Dimension(32)])
# mixed/tower_2/conv/batchnorm Input  mixed/tower_2/conv/batchnorm/beta:0 TensorShape([Dimension(32)])
# mixed/tower_2/conv/batchnorm Input  mixed/tower_2/conv/batchnorm/gamma:0 TensorShape([Dimension(32)])
# mixed/tower_2/conv/batchnorm Output  mixed/tower_2/conv/batchnorm:0
#
#
# Operation: mixed/tower_2/conv/CheckNumerics
# mixed/tower_2/conv/CheckNumerics Input  mixed/tower_2/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(32)])
# mixed/tower_2/conv/CheckNumerics Output  mixed/tower_2/conv/CheckNumerics:0
#
#
# Operation: mixed/tower_2/conv/control_dependency
# mixed/tower_2/conv/control_dependency Input  mixed/tower_2/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(32)])
# mixed/tower_2/conv/control_dependency Output  mixed/tower_2/conv/control_dependency:0
#
#
# Operation: mixed/tower_2/conv
# mixed/tower_2/conv Input  mixed/tower_2/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(32)])
# mixed/tower_2/conv Output  mixed/tower_2/conv:0
#
#
# Operation: mixed/join/concat_dim
# mixed/join/concat_dim Output  mixed/join/concat_dim:0
#
#
# Operation: mixed/join
# mixed/join Input  mixed/join/concat_dim:0 TensorShape([])
# mixed/join Input  mixed/conv:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/join Input  mixed/tower/conv_1:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed/join Input  mixed/tower_1/conv_2:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed/join Input  mixed/tower_2/conv:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(32)])
# mixed/join Output  mixed/join:0
#
#
# Operation: mixed_1/conv/conv2d_params
# mixed_1/conv/conv2d_params Output  mixed_1/conv/conv2d_params:0
#
#
# Operation: mixed_1/conv/Conv2D
# mixed_1/conv/Conv2D Input  mixed/join:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(256)])
# mixed_1/conv/Conv2D Input  mixed_1/conv/conv2d_params:0 TensorShape([Dimension(1), Dimension(1), Dimension(256), Dimension(64)])
# mixed_1/conv/Conv2D Output  mixed_1/conv/Conv2D:0
#
#
# Operation: mixed_1/conv/batchnorm/beta
# mixed_1/conv/batchnorm/beta Output  mixed_1/conv/batchnorm/beta:0
#
#
# Operation: mixed_1/conv/batchnorm/gamma
# mixed_1/conv/batchnorm/gamma Output  mixed_1/conv/batchnorm/gamma:0
#
#
# Operation: mixed_1/conv/batchnorm/moving_mean
# mixed_1/conv/batchnorm/moving_mean Output  mixed_1/conv/batchnorm/moving_mean:0
#
#
# Operation: mixed_1/conv/batchnorm/moving_variance
# mixed_1/conv/batchnorm/moving_variance Output  mixed_1/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed_1/conv/batchnorm
# mixed_1/conv/batchnorm Input  mixed_1/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/conv/batchnorm Input  mixed_1/conv/batchnorm/moving_mean:0 TensorShape([Dimension(64)])
# mixed_1/conv/batchnorm Input  mixed_1/conv/batchnorm/moving_variance:0 TensorShape([Dimension(64)])
# mixed_1/conv/batchnorm Input  mixed_1/conv/batchnorm/beta:0 TensorShape([Dimension(64)])
# mixed_1/conv/batchnorm Input  mixed_1/conv/batchnorm/gamma:0 TensorShape([Dimension(64)])
# mixed_1/conv/batchnorm Output  mixed_1/conv/batchnorm:0
#
#
# Operation: mixed_1/conv/CheckNumerics
# mixed_1/conv/CheckNumerics Input  mixed_1/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/conv/CheckNumerics Output  mixed_1/conv/CheckNumerics:0
#
#
# Operation: mixed_1/conv/control_dependency
# mixed_1/conv/control_dependency Input  mixed_1/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/conv/control_dependency Output  mixed_1/conv/control_dependency:0
#
#
# Operation: mixed_1/conv
# mixed_1/conv Input  mixed_1/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/conv Output  mixed_1/conv:0
#
#
# Operation: mixed_1/tower/conv/conv2d_params
# mixed_1/tower/conv/conv2d_params Output  mixed_1/tower/conv/conv2d_params:0
#
#
# Operation: mixed_1/tower/conv/Conv2D
# mixed_1/tower/conv/Conv2D Input  mixed/join:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(256)])
# mixed_1/tower/conv/Conv2D Input  mixed_1/tower/conv/conv2d_params:0 TensorShape([Dimension(1), Dimension(1), Dimension(256), Dimension(48)])
# mixed_1/tower/conv/Conv2D Output  mixed_1/tower/conv/Conv2D:0
#
#
# Operation: mixed_1/tower/conv/batchnorm/beta
# mixed_1/tower/conv/batchnorm/beta Output  mixed_1/tower/conv/batchnorm/beta:0
#
#
# Operation: mixed_1/tower/conv/batchnorm/gamma
# mixed_1/tower/conv/batchnorm/gamma Output  mixed_1/tower/conv/batchnorm/gamma:0
#
#
# Operation: mixed_1/tower/conv/batchnorm/moving_mean
# mixed_1/tower/conv/batchnorm/moving_mean Output  mixed_1/tower/conv/batchnorm/moving_mean:0
#
#
# Operation: mixed_1/tower/conv/batchnorm/moving_variance
# mixed_1/tower/conv/batchnorm/moving_variance Output  mixed_1/tower/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed_1/tower/conv/batchnorm
# mixed_1/tower/conv/batchnorm Input  mixed_1/tower/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(48)])
# mixed_1/tower/conv/batchnorm Input  mixed_1/tower/conv/batchnorm/moving_mean:0 TensorShape([Dimension(48)])
# mixed_1/tower/conv/batchnorm Input  mixed_1/tower/conv/batchnorm/moving_variance:0 TensorShape([Dimension(48)])
# mixed_1/tower/conv/batchnorm Input  mixed_1/tower/conv/batchnorm/beta:0 TensorShape([Dimension(48)])
# mixed_1/tower/conv/batchnorm Input  mixed_1/tower/conv/batchnorm/gamma:0 TensorShape([Dimension(48)])
# mixed_1/tower/conv/batchnorm Output  mixed_1/tower/conv/batchnorm:0
#
#
# Operation: mixed_1/tower/conv/CheckNumerics
# mixed_1/tower/conv/CheckNumerics Input  mixed_1/tower/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(48)])
# mixed_1/tower/conv/CheckNumerics Output  mixed_1/tower/conv/CheckNumerics:0
#
#
# Operation: mixed_1/tower/conv/control_dependency
# mixed_1/tower/conv/control_dependency Input  mixed_1/tower/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(48)])
# mixed_1/tower/conv/control_dependency Output  mixed_1/tower/conv/control_dependency:0
#
#
# Operation: mixed_1/tower/conv
# mixed_1/tower/conv Input  mixed_1/tower/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(48)])
# mixed_1/tower/conv Output  mixed_1/tower/conv:0
#
#
# Operation: mixed_1/tower/conv_1/conv2d_params
# mixed_1/tower/conv_1/conv2d_params Output  mixed_1/tower/conv_1/conv2d_params:0
#
#
# Operation: mixed_1/tower/conv_1/Conv2D
# mixed_1/tower/conv_1/Conv2D Input  mixed_1/tower/conv:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(48)])
# mixed_1/tower/conv_1/Conv2D Input  mixed_1/tower/conv_1/conv2d_params:0 TensorShape([Dimension(5), Dimension(5), Dimension(48), Dimension(64)])
# mixed_1/tower/conv_1/Conv2D Output  mixed_1/tower/conv_1/Conv2D:0
#
#
# Operation: mixed_1/tower/conv_1/batchnorm/beta
# mixed_1/tower/conv_1/batchnorm/beta Output  mixed_1/tower/conv_1/batchnorm/beta:0
#
#
# Operation: mixed_1/tower/conv_1/batchnorm/gamma
# mixed_1/tower/conv_1/batchnorm/gamma Output  mixed_1/tower/conv_1/batchnorm/gamma:0
#
#
# Operation: mixed_1/tower/conv_1/batchnorm/moving_mean
# mixed_1/tower/conv_1/batchnorm/moving_mean Output  mixed_1/tower/conv_1/batchnorm/moving_mean:0
#
#
# Operation: mixed_1/tower/conv_1/batchnorm/moving_variance
# mixed_1/tower/conv_1/batchnorm/moving_variance Output  mixed_1/tower/conv_1/batchnorm/moving_variance:0
#
#
# Operation: mixed_1/tower/conv_1/batchnorm
# mixed_1/tower/conv_1/batchnorm Input  mixed_1/tower/conv_1/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower/conv_1/batchnorm Input  mixed_1/tower/conv_1/batchnorm/moving_mean:0 TensorShape([Dimension(64)])
# mixed_1/tower/conv_1/batchnorm Input  mixed_1/tower/conv_1/batchnorm/moving_variance:0 TensorShape([Dimension(64)])
# mixed_1/tower/conv_1/batchnorm Input  mixed_1/tower/conv_1/batchnorm/beta:0 TensorShape([Dimension(64)])
# mixed_1/tower/conv_1/batchnorm Input  mixed_1/tower/conv_1/batchnorm/gamma:0 TensorShape([Dimension(64)])
# mixed_1/tower/conv_1/batchnorm Output  mixed_1/tower/conv_1/batchnorm:0
#
#
# Operation: mixed_1/tower/conv_1/CheckNumerics
# mixed_1/tower/conv_1/CheckNumerics Input  mixed_1/tower/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower/conv_1/CheckNumerics Output  mixed_1/tower/conv_1/CheckNumerics:0
#
#
# Operation: mixed_1/tower/conv_1/control_dependency
# mixed_1/tower/conv_1/control_dependency Input  mixed_1/tower/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower/conv_1/control_dependency Output  mixed_1/tower/conv_1/control_dependency:0
#
#
# Operation: mixed_1/tower/conv_1
# mixed_1/tower/conv_1 Input  mixed_1/tower/conv_1/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower/conv_1 Output  mixed_1/tower/conv_1:0
#
#
# Operation: mixed_1/tower_1/conv/conv2d_params
# mixed_1/tower_1/conv/conv2d_params Output  mixed_1/tower_1/conv/conv2d_params:0
#
#
# Operation: mixed_1/tower_1/conv/Conv2D
# mixed_1/tower_1/conv/Conv2D Input  mixed/join:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(256)])
# mixed_1/tower_1/conv/Conv2D Input  mixed_1/tower_1/conv/conv2d_params:0 TensorShape([Dimension(1), Dimension(1), Dimension(256), Dimension(64)])
# mixed_1/tower_1/conv/Conv2D Output  mixed_1/tower_1/conv/Conv2D:0
#
#
# Operation: mixed_1/tower_1/conv/batchnorm/beta
# mixed_1/tower_1/conv/batchnorm/beta Output  mixed_1/tower_1/conv/batchnorm/beta:0
#
#
# Operation: mixed_1/tower_1/conv/batchnorm/gamma
# mixed_1/tower_1/conv/batchnorm/gamma Output  mixed_1/tower_1/conv/batchnorm/gamma:0
#
#
# Operation: mixed_1/tower_1/conv/batchnorm/moving_mean
# mixed_1/tower_1/conv/batchnorm/moving_mean Output  mixed_1/tower_1/conv/batchnorm/moving_mean:0
#
#
# Operation: mixed_1/tower_1/conv/batchnorm/moving_variance
# mixed_1/tower_1/conv/batchnorm/moving_variance Output  mixed_1/tower_1/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed_1/tower_1/conv/batchnorm
# mixed_1/tower_1/conv/batchnorm Input  mixed_1/tower_1/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower_1/conv/batchnorm Input  mixed_1/tower_1/conv/batchnorm/moving_mean:0 TensorShape([Dimension(64)])
# mixed_1/tower_1/conv/batchnorm Input  mixed_1/tower_1/conv/batchnorm/moving_variance:0 TensorShape([Dimension(64)])
# mixed_1/tower_1/conv/batchnorm Input  mixed_1/tower_1/conv/batchnorm/beta:0 TensorShape([Dimension(64)])
# mixed_1/tower_1/conv/batchnorm Input  mixed_1/tower_1/conv/batchnorm/gamma:0 TensorShape([Dimension(64)])
# mixed_1/tower_1/conv/batchnorm Output  mixed_1/tower_1/conv/batchnorm:0
#
#
# Operation: mixed_1/tower_1/conv/CheckNumerics
# mixed_1/tower_1/conv/CheckNumerics Input  mixed_1/tower_1/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower_1/conv/CheckNumerics Output  mixed_1/tower_1/conv/CheckNumerics:0
#
#
# Operation: mixed_1/tower_1/conv/control_dependency
# mixed_1/tower_1/conv/control_dependency Input  mixed_1/tower_1/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower_1/conv/control_dependency Output  mixed_1/tower_1/conv/control_dependency:0
#
#
# Operation: mixed_1/tower_1/conv
# mixed_1/tower_1/conv Input  mixed_1/tower_1/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower_1/conv Output  mixed_1/tower_1/conv:0
#
#
# Operation: mixed_1/tower_1/conv_1/conv2d_params
# mixed_1/tower_1/conv_1/conv2d_params Output  mixed_1/tower_1/conv_1/conv2d_params:0
#
#
# Operation: mixed_1/tower_1/conv_1/Conv2D
# mixed_1/tower_1/conv_1/Conv2D Input  mixed_1/tower_1/conv:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower_1/conv_1/Conv2D Input  mixed_1/tower_1/conv_1/conv2d_params:0 TensorShape([Dimension(3), Dimension(3), Dimension(64), Dimension(96)])
# mixed_1/tower_1/conv_1/Conv2D Output  mixed_1/tower_1/conv_1/Conv2D:0
#
#
# Operation: mixed_1/tower_1/conv_1/batchnorm/beta
# mixed_1/tower_1/conv_1/batchnorm/beta Output  mixed_1/tower_1/conv_1/batchnorm/beta:0
#
#
# Operation: mixed_1/tower_1/conv_1/batchnorm/gamma
# mixed_1/tower_1/conv_1/batchnorm/gamma Output  mixed_1/tower_1/conv_1/batchnorm/gamma:0
#
#
# Operation: mixed_1/tower_1/conv_1/batchnorm/moving_mean
# mixed_1/tower_1/conv_1/batchnorm/moving_mean Output  mixed_1/tower_1/conv_1/batchnorm/moving_mean:0
#
#
# Operation: mixed_1/tower_1/conv_1/batchnorm/moving_variance
# mixed_1/tower_1/conv_1/batchnorm/moving_variance Output  mixed_1/tower_1/conv_1/batchnorm/moving_variance:0
#
#
# Operation: mixed_1/tower_1/conv_1/batchnorm
# mixed_1/tower_1/conv_1/batchnorm Input  mixed_1/tower_1/conv_1/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed_1/tower_1/conv_1/batchnorm Input  mixed_1/tower_1/conv_1/batchnorm/moving_mean:0 TensorShape([Dimension(96)])
# mixed_1/tower_1/conv_1/batchnorm Input  mixed_1/tower_1/conv_1/batchnorm/moving_variance:0 TensorShape([Dimension(96)])
# mixed_1/tower_1/conv_1/batchnorm Input  mixed_1/tower_1/conv_1/batchnorm/beta:0 TensorShape([Dimension(96)])
# mixed_1/tower_1/conv_1/batchnorm Input  mixed_1/tower_1/conv_1/batchnorm/gamma:0 TensorShape([Dimension(96)])
# mixed_1/tower_1/conv_1/batchnorm Output  mixed_1/tower_1/conv_1/batchnorm:0
#
#
# Operation: mixed_1/tower_1/conv_1/CheckNumerics
# mixed_1/tower_1/conv_1/CheckNumerics Input  mixed_1/tower_1/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed_1/tower_1/conv_1/CheckNumerics Output  mixed_1/tower_1/conv_1/CheckNumerics:0
#
#
# Operation: mixed_1/tower_1/conv_1/control_dependency
# mixed_1/tower_1/conv_1/control_dependency Input  mixed_1/tower_1/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed_1/tower_1/conv_1/control_dependency Output  mixed_1/tower_1/conv_1/control_dependency:0
#
#
# Operation: mixed_1/tower_1/conv_1
# mixed_1/tower_1/conv_1 Input  mixed_1/tower_1/conv_1/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed_1/tower_1/conv_1 Output  mixed_1/tower_1/conv_1:0
#
#
# Operation: mixed_1/tower_1/conv_2/conv2d_params
# mixed_1/tower_1/conv_2/conv2d_params Output  mixed_1/tower_1/conv_2/conv2d_params:0
#
#
# Operation: mixed_1/tower_1/conv_2/Conv2D
# mixed_1/tower_1/conv_2/Conv2D Input  mixed_1/tower_1/conv_1:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed_1/tower_1/conv_2/Conv2D Input  mixed_1/tower_1/conv_2/conv2d_params:0 TensorShape([Dimension(3), Dimension(3), Dimension(96), Dimension(96)])
# mixed_1/tower_1/conv_2/Conv2D Output  mixed_1/tower_1/conv_2/Conv2D:0
#
#
# Operation: mixed_1/tower_1/conv_2/batchnorm/beta
# mixed_1/tower_1/conv_2/batchnorm/beta Output  mixed_1/tower_1/conv_2/batchnorm/beta:0
#
#
# Operation: mixed_1/tower_1/conv_2/batchnorm/gamma
# mixed_1/tower_1/conv_2/batchnorm/gamma Output  mixed_1/tower_1/conv_2/batchnorm/gamma:0
#
#
# Operation: mixed_1/tower_1/conv_2/batchnorm/moving_mean
# mixed_1/tower_1/conv_2/batchnorm/moving_mean Output  mixed_1/tower_1/conv_2/batchnorm/moving_mean:0
#
#
# Operation: mixed_1/tower_1/conv_2/batchnorm/moving_variance
# mixed_1/tower_1/conv_2/batchnorm/moving_variance Output  mixed_1/tower_1/conv_2/batchnorm/moving_variance:0
#
#
# Operation: mixed_1/tower_1/conv_2/batchnorm
# mixed_1/tower_1/conv_2/batchnorm Input  mixed_1/tower_1/conv_2/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed_1/tower_1/conv_2/batchnorm Input  mixed_1/tower_1/conv_2/batchnorm/moving_mean:0 TensorShape([Dimension(96)])
# mixed_1/tower_1/conv_2/batchnorm Input  mixed_1/tower_1/conv_2/batchnorm/moving_variance:0 TensorShape([Dimension(96)])
# mixed_1/tower_1/conv_2/batchnorm Input  mixed_1/tower_1/conv_2/batchnorm/beta:0 TensorShape([Dimension(96)])
# mixed_1/tower_1/conv_2/batchnorm Input  mixed_1/tower_1/conv_2/batchnorm/gamma:0 TensorShape([Dimension(96)])
# mixed_1/tower_1/conv_2/batchnorm Output  mixed_1/tower_1/conv_2/batchnorm:0
#
#
# Operation: mixed_1/tower_1/conv_2/CheckNumerics
# mixed_1/tower_1/conv_2/CheckNumerics Input  mixed_1/tower_1/conv_2/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed_1/tower_1/conv_2/CheckNumerics Output  mixed_1/tower_1/conv_2/CheckNumerics:0
#
#
# Operation: mixed_1/tower_1/conv_2/control_dependency
# mixed_1/tower_1/conv_2/control_dependency Input  mixed_1/tower_1/conv_2/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed_1/tower_1/conv_2/control_dependency Output  mixed_1/tower_1/conv_2/control_dependency:0
#
#
# Operation: mixed_1/tower_1/conv_2
# mixed_1/tower_1/conv_2 Input  mixed_1/tower_1/conv_2/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(96)])
# mixed_1/tower_1/conv_2 Output  mixed_1/tower_1/conv_2:0
#
#
# Operation: mixed_1/tower_2/pool
# mixed_1/tower_2/pool Input  mixed/join:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(256)])
# mixed_1/tower_2/pool Output  mixed_1/tower_2/pool:0
#
#
# Operation: mixed_1/tower_2/conv/conv2d_params
# mixed_1/tower_2/conv/conv2d_params Output  mixed_1/tower_2/conv/conv2d_params:0
#
#
# Operation: mixed_1/tower_2/conv/Conv2D
# mixed_1/tower_2/conv/Conv2D Input  mixed_1/tower_2/pool:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(256)])
# mixed_1/tower_2/conv/Conv2D Input  mixed_1/tower_2/conv/conv2d_params:0 TensorShape([Dimension(1), Dimension(1), Dimension(256), Dimension(64)])
# mixed_1/tower_2/conv/Conv2D Output  mixed_1/tower_2/conv/Conv2D:0
#
#
# Operation: mixed_1/tower_2/conv/batchnorm/beta
# mixed_1/tower_2/conv/batchnorm/beta Output  mixed_1/tower_2/conv/batchnorm/beta:0
#
#
# Operation: mixed_1/tower_2/conv/batchnorm/gamma
# mixed_1/tower_2/conv/batchnorm/gamma Output  mixed_1/tower_2/conv/batchnorm/gamma:0
#
#
# Operation: mixed_1/tower_2/conv/batchnorm/moving_mean
# mixed_1/tower_2/conv/batchnorm/moving_mean Output  mixed_1/tower_2/conv/batchnorm/moving_mean:0
#
#
# Operation: mixed_1/tower_2/conv/batchnorm/moving_variance
# mixed_1/tower_2/conv/batchnorm/moving_variance Output  mixed_1/tower_2/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed_1/tower_2/conv/batchnorm
# mixed_1/tower_2/conv/batchnorm Input  mixed_1/tower_2/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower_2/conv/batchnorm Input  mixed_1/tower_2/conv/batchnorm/moving_mean:0 TensorShape([Dimension(64)])
# mixed_1/tower_2/conv/batchnorm Input  mixed_1/tower_2/conv/batchnorm/moving_variance:0 TensorShape([Dimension(64)])
# mixed_1/tower_2/conv/batchnorm Input  mixed_1/tower_2/conv/batchnorm/beta:0 TensorShape([Dimension(64)])
# mixed_1/tower_2/conv/batchnorm Input  mixed_1/tower_2/conv/batchnorm/gamma:0 TensorShape([Dimension(64)])
# mixed_1/tower_2/conv/batchnorm Output  mixed_1/tower_2/conv/batchnorm:0
#
#
# Operation: mixed_1/tower_2/conv/CheckNumerics
# mixed_1/tower_2/conv/CheckNumerics Input  mixed_1/tower_2/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower_2/conv/CheckNumerics Output  mixed_1/tower_2/conv/CheckNumerics:0
#
#
# Operation: mixed_1/tower_2/conv/control_dependency
# mixed_1/tower_2/conv/control_dependency Input  mixed_1/tower_2/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower_2/conv/control_dependency Output  mixed_1/tower_2/conv/control_dependency:0
#
#
# Operation: mixed_1/tower_2/conv
# mixed_1/tower_2/conv Input  mixed_1/tower_2/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(35), Dimension(35), Dimension(64)])
# mixed_1/tower_2/conv Output  mixed_1/tower_2/conv:0
#
#
# Operation: mixed_1/join/concat_dim
# ...
# mixed_10/tower_1/conv/batchnorm/moving_variance Output  mixed_10/tower_1/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed_10/tower_1/conv/batchnorm
# mixed_10/tower_1/conv/batchnorm Input  mixed_10/tower_1/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(448)])
# mixed_10/tower_1/conv/batchnorm Input  mixed_10/tower_1/conv/batchnorm/moving_mean:0 TensorShape([Dimension(448)])
# mixed_10/tower_1/conv/batchnorm Input  mixed_10/tower_1/conv/batchnorm/moving_variance:0 TensorShape([Dimension(448)])
# mixed_10/tower_1/conv/batchnorm Input  mixed_10/tower_1/conv/batchnorm/beta:0 TensorShape([Dimension(448)])
# mixed_10/tower_1/conv/batchnorm Input  mixed_10/tower_1/conv/batchnorm/gamma:0 TensorShape([Dimension(448)])
# mixed_10/tower_1/conv/batchnorm Output  mixed_10/tower_1/conv/batchnorm:0
#
#
# Operation: mixed_10/tower_1/conv/CheckNumerics
# mixed_10/tower_1/conv/CheckNumerics Input  mixed_10/tower_1/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(448)])
# mixed_10/tower_1/conv/CheckNumerics Output  mixed_10/tower_1/conv/CheckNumerics:0
#
#
# Operation: mixed_10/tower_1/conv/control_dependency
# mixed_10/tower_1/conv/control_dependency Input  mixed_10/tower_1/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(448)])
# mixed_10/tower_1/conv/control_dependency Output  mixed_10/tower_1/conv/control_dependency:0
#
#
# Operation: mixed_10/tower_1/conv
# mixed_10/tower_1/conv Input  mixed_10/tower_1/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(448)])
# mixed_10/tower_1/conv Output  mixed_10/tower_1/conv:0
#
#
# Operation: mixed_10/tower_1/conv_1/conv2d_params
# mixed_10/tower_1/conv_1/conv2d_params Output  mixed_10/tower_1/conv_1/conv2d_params:0
#
#
# Operation: mixed_10/tower_1/conv_1/Conv2D
# mixed_10/tower_1/conv_1/Conv2D Input  mixed_10/tower_1/conv:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(448)])
# mixed_10/tower_1/conv_1/Conv2D Input  mixed_10/tower_1/conv_1/conv2d_params:0 TensorShape([Dimension(3), Dimension(3), Dimension(448), Dimension(384)])
# mixed_10/tower_1/conv_1/Conv2D Output  mixed_10/tower_1/conv_1/Conv2D:0
#
#
# Operation: mixed_10/tower_1/conv_1/batchnorm/beta
# mixed_10/tower_1/conv_1/batchnorm/beta Output  mixed_10/tower_1/conv_1/batchnorm/beta:0
#
#
# Operation: mixed_10/tower_1/conv_1/batchnorm/gamma
# mixed_10/tower_1/conv_1/batchnorm/gamma Output  mixed_10/tower_1/conv_1/batchnorm/gamma:0
#
#
# Operation: mixed_10/tower_1/conv_1/batchnorm/moving_mean
# mixed_10/tower_1/conv_1/batchnorm/moving_mean Output  mixed_10/tower_1/conv_1/batchnorm/moving_mean:0
#
#
# Operation: mixed_10/tower_1/conv_1/batchnorm/moving_variance
# mixed_10/tower_1/conv_1/batchnorm/moving_variance Output  mixed_10/tower_1/conv_1/batchnorm/moving_variance:0
#
#
# Operation: mixed_10/tower_1/conv_1/batchnorm
# mixed_10/tower_1/conv_1/batchnorm Input  mixed_10/tower_1/conv_1/Conv2D:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/conv_1/batchnorm Input  mixed_10/tower_1/conv_1/batchnorm/moving_mean:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/conv_1/batchnorm Input  mixed_10/tower_1/conv_1/batchnorm/moving_variance:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/conv_1/batchnorm Input  mixed_10/tower_1/conv_1/batchnorm/beta:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/conv_1/batchnorm Input  mixed_10/tower_1/conv_1/batchnorm/gamma:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/conv_1/batchnorm Output  mixed_10/tower_1/conv_1/batchnorm:0
#
#
# Operation: mixed_10/tower_1/conv_1/CheckNumerics
# mixed_10/tower_1/conv_1/CheckNumerics Input  mixed_10/tower_1/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/conv_1/CheckNumerics Output  mixed_10/tower_1/conv_1/CheckNumerics:0
#
#
# Operation: mixed_10/tower_1/conv_1/control_dependency
# mixed_10/tower_1/conv_1/control_dependency Input  mixed_10/tower_1/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/conv_1/control_dependency Output  mixed_10/tower_1/conv_1/control_dependency:0
#
#
# Operation: mixed_10/tower_1/conv_1
# mixed_10/tower_1/conv_1 Input  mixed_10/tower_1/conv_1/control_dependency:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/conv_1 Output  mixed_10/tower_1/conv_1:0
#
#
# Operation: mixed_10/tower_1/mixed/conv/conv2d_params
# mixed_10/tower_1/mixed/conv/conv2d_params Output  mixed_10/tower_1/mixed/conv/conv2d_params:0
#
#
# Operation: mixed_10/tower_1/mixed/conv/Conv2D
# mixed_10/tower_1/mixed/conv/Conv2D Input  mixed_10/tower_1/conv_1:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/mixed/conv/Conv2D Input  mixed_10/tower_1/mixed/conv/conv2d_params:0 TensorShape([Dimension(1), Dimension(3), Dimension(384), Dimension(384)])
# mixed_10/tower_1/mixed/conv/Conv2D Output  mixed_10/tower_1/mixed/conv/Conv2D:0
#
#
# Operation: mixed_10/tower_1/mixed/conv/batchnorm/beta
# mixed_10/tower_1/mixed/conv/batchnorm/beta Output  mixed_10/tower_1/mixed/conv/batchnorm/beta:0
#
#
# Operation: mixed_10/tower_1/mixed/conv/batchnorm/gamma
# mixed_10/tower_1/mixed/conv/batchnorm/gamma Output  mixed_10/tower_1/mixed/conv/batchnorm/gamma:0
#
#
# Operation: mixed_10/tower_1/mixed/conv/batchnorm/moving_mean
# mixed_10/tower_1/mixed/conv/batchnorm/moving_mean Output  mixed_10/tower_1/mixed/conv/batchnorm/moving_mean:0
#
#
# Operation: mixed_10/tower_1/mixed/conv/batchnorm/moving_variance
# mixed_10/tower_1/mixed/conv/batchnorm/moving_variance Output  mixed_10/tower_1/mixed/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed_10/tower_1/mixed/conv/batchnorm
# mixed_10/tower_1/mixed/conv/batchnorm Input  mixed_10/tower_1/mixed/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/mixed/conv/batchnorm Input  mixed_10/tower_1/mixed/conv/batchnorm/moving_mean:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/mixed/conv/batchnorm Input  mixed_10/tower_1/mixed/conv/batchnorm/moving_variance:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/mixed/conv/batchnorm Input  mixed_10/tower_1/mixed/conv/batchnorm/beta:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/mixed/conv/batchnorm Input  mixed_10/tower_1/mixed/conv/batchnorm/gamma:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/mixed/conv/batchnorm Output  mixed_10/tower_1/mixed/conv/batchnorm:0
#
#
# Operation: mixed_10/tower_1/mixed/conv/CheckNumerics
# mixed_10/tower_1/mixed/conv/CheckNumerics Input  mixed_10/tower_1/mixed/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/mixed/conv/CheckNumerics Output  mixed_10/tower_1/mixed/conv/CheckNumerics:0
#
#
# Operation: mixed_10/tower_1/mixed/conv/control_dependency
# mixed_10/tower_1/mixed/conv/control_dependency Input  mixed_10/tower_1/mixed/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/mixed/conv/control_dependency Output  mixed_10/tower_1/mixed/conv/control_dependency:0
#
#
# Operation: mixed_10/tower_1/mixed/conv
# mixed_10/tower_1/mixed/conv Input  mixed_10/tower_1/mixed/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/mixed/conv Output  mixed_10/tower_1/mixed/conv:0
#
#
# Operation: mixed_10/tower_1/mixed/conv_1/conv2d_params
# mixed_10/tower_1/mixed/conv_1/conv2d_params Output  mixed_10/tower_1/mixed/conv_1/conv2d_params:0
#
#
# Operation: mixed_10/tower_1/mixed/conv_1/Conv2D
# mixed_10/tower_1/mixed/conv_1/Conv2D Input  mixed_10/tower_1/conv_1:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/mixed/conv_1/Conv2D Input  mixed_10/tower_1/mixed/conv_1/conv2d_params:0 TensorShape([Dimension(3), Dimension(1), Dimension(384), Dimension(384)])
# mixed_10/tower_1/mixed/conv_1/Conv2D Output  mixed_10/tower_1/mixed/conv_1/Conv2D:0
#
#
# Operation: mixed_10/tower_1/mixed/conv_1/batchnorm/beta
# mixed_10/tower_1/mixed/conv_1/batchnorm/beta Output  mixed_10/tower_1/mixed/conv_1/batchnorm/beta:0
#
#
# Operation: mixed_10/tower_1/mixed/conv_1/batchnorm/gamma
# mixed_10/tower_1/mixed/conv_1/batchnorm/gamma Output  mixed_10/tower_1/mixed/conv_1/batchnorm/gamma:0
#
#
# Operation: mixed_10/tower_1/mixed/conv_1/batchnorm/moving_mean
# mixed_10/tower_1/mixed/conv_1/batchnorm/moving_mean Output  mixed_10/tower_1/mixed/conv_1/batchnorm/moving_mean:0
#
#
# Operation: mixed_10/tower_1/mixed/conv_1/batchnorm/moving_variance
# mixed_10/tower_1/mixed/conv_1/batchnorm/moving_variance Output  mixed_10/tower_1/mixed/conv_1/batchnorm/moving_variance:0
#
#
# Operation: mixed_10/tower_1/mixed/conv_1/batchnorm
# mixed_10/tower_1/mixed/conv_1/batchnorm Input  mixed_10/tower_1/mixed/conv_1/Conv2D:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/mixed/conv_1/batchnorm Input  mixed_10/tower_1/mixed/conv_1/batchnorm/moving_mean:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/mixed/conv_1/batchnorm Input  mixed_10/tower_1/mixed/conv_1/batchnorm/moving_variance:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/mixed/conv_1/batchnorm Input  mixed_10/tower_1/mixed/conv_1/batchnorm/beta:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/mixed/conv_1/batchnorm Input  mixed_10/tower_1/mixed/conv_1/batchnorm/gamma:0 TensorShape([Dimension(384)])
# mixed_10/tower_1/mixed/conv_1/batchnorm Output  mixed_10/tower_1/mixed/conv_1/batchnorm:0
#
#
# Operation: mixed_10/tower_1/mixed/conv_1/CheckNumerics
# mixed_10/tower_1/mixed/conv_1/CheckNumerics Input  mixed_10/tower_1/mixed/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/mixed/conv_1/CheckNumerics Output  mixed_10/tower_1/mixed/conv_1/CheckNumerics:0
#
#
# Operation: mixed_10/tower_1/mixed/conv_1/control_dependency
# mixed_10/tower_1/mixed/conv_1/control_dependency Input  mixed_10/tower_1/mixed/conv_1/batchnorm:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/mixed/conv_1/control_dependency Output  mixed_10/tower_1/mixed/conv_1/control_dependency:0
#
#
# Operation: mixed_10/tower_1/mixed/conv_1
# mixed_10/tower_1/mixed/conv_1 Input  mixed_10/tower_1/mixed/conv_1/control_dependency:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/tower_1/mixed/conv_1 Output  mixed_10/tower_1/mixed/conv_1:0
#
#
# Operation: mixed_10/tower_2/pool/CheckNumerics
# mixed_10/tower_2/pool/CheckNumerics Input  mixed_9/join:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(2048)])
# mixed_10/tower_2/pool/CheckNumerics Output  mixed_10/tower_2/pool/CheckNumerics:0
#
#
# Operation: mixed_10/tower_2/pool/control_dependency
# mixed_10/tower_2/pool/control_dependency Input  mixed_9/join:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(2048)])
# mixed_10/tower_2/pool/control_dependency Output  mixed_10/tower_2/pool/control_dependency:0
#
#
# Operation: mixed_10/tower_2/pool
# mixed_10/tower_2/pool Input  mixed_10/tower_2/pool/control_dependency:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(2048)])
# mixed_10/tower_2/pool Output  mixed_10/tower_2/pool:0
#
#
# Operation: mixed_10/tower_2/conv/conv2d_params
# mixed_10/tower_2/conv/conv2d_params Output  mixed_10/tower_2/conv/conv2d_params:0
#
#
# Operation: mixed_10/tower_2/conv/Conv2D
# mixed_10/tower_2/conv/Conv2D Input  mixed_10/tower_2/pool:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(2048)])
# mixed_10/tower_2/conv/Conv2D Input  mixed_10/tower_2/conv/conv2d_params:0 TensorShape([Dimension(1), Dimension(1), Dimension(2048), Dimension(192)])
# mixed_10/tower_2/conv/Conv2D Output  mixed_10/tower_2/conv/Conv2D:0
#
#
# Operation: mixed_10/tower_2/conv/batchnorm/beta
# mixed_10/tower_2/conv/batchnorm/beta Output  mixed_10/tower_2/conv/batchnorm/beta:0
#
#
# Operation: mixed_10/tower_2/conv/batchnorm/gamma
# mixed_10/tower_2/conv/batchnorm/gamma Output  mixed_10/tower_2/conv/batchnorm/gamma:0
#
#
# Operation: mixed_10/tower_2/conv/batchnorm/moving_mean
# mixed_10/tower_2/conv/batchnorm/moving_mean Output  mixed_10/tower_2/conv/batchnorm/moving_mean:0
#
#
# Operation: mixed_10/tower_2/conv/batchnorm/moving_variance
# mixed_10/tower_2/conv/batchnorm/moving_variance Output  mixed_10/tower_2/conv/batchnorm/moving_variance:0
#
#
# Operation: mixed_10/tower_2/conv/batchnorm
# mixed_10/tower_2/conv/batchnorm Input  mixed_10/tower_2/conv/Conv2D:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(192)])
# mixed_10/tower_2/conv/batchnorm Input  mixed_10/tower_2/conv/batchnorm/moving_mean:0 TensorShape([Dimension(192)])
# mixed_10/tower_2/conv/batchnorm Input  mixed_10/tower_2/conv/batchnorm/moving_variance:0 TensorShape([Dimension(192)])
# mixed_10/tower_2/conv/batchnorm Input  mixed_10/tower_2/conv/batchnorm/beta:0 TensorShape([Dimension(192)])
# mixed_10/tower_2/conv/batchnorm Input  mixed_10/tower_2/conv/batchnorm/gamma:0 TensorShape([Dimension(192)])
# mixed_10/tower_2/conv/batchnorm Output  mixed_10/tower_2/conv/batchnorm:0
#
#
# Operation: mixed_10/tower_2/conv/CheckNumerics
# mixed_10/tower_2/conv/CheckNumerics Input  mixed_10/tower_2/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(192)])
# mixed_10/tower_2/conv/CheckNumerics Output  mixed_10/tower_2/conv/CheckNumerics:0
#
#
# Operation: mixed_10/tower_2/conv/control_dependency
# mixed_10/tower_2/conv/control_dependency Input  mixed_10/tower_2/conv/batchnorm:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(192)])
# mixed_10/tower_2/conv/control_dependency Output  mixed_10/tower_2/conv/control_dependency:0
#
#
# Operation: mixed_10/tower_2/conv
# mixed_10/tower_2/conv Input  mixed_10/tower_2/conv/control_dependency:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(192)])
# mixed_10/tower_2/conv Output  mixed_10/tower_2/conv:0
#
#
# Operation: mixed_10/join/concat_dim
# mixed_10/join/concat_dim Output  mixed_10/join/concat_dim:0
#
#
# Operation: mixed_10/join
# mixed_10/join Input  mixed_10/join/concat_dim:0 TensorShape([])
# mixed_10/join Input  mixed_10/conv:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(320)])
# mixed_10/join Input  mixed_10/tower/mixed/conv:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/join Input  mixed_10/tower/mixed/conv_1:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/join Input  mixed_10/tower_1/mixed/conv:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/join Input  mixed_10/tower_1/mixed/conv_1:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(384)])
# mixed_10/join Input  mixed_10/tower_2/conv:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(192)])
# mixed_10/join Output  mixed_10/join:0
#
#
# Operation: pool_3
# pool_3 Input  mixed_10/join:0 TensorShape([Dimension(1), Dimension(8), Dimension(8), Dimension(2048)])
# pool_3 Output  pool_3:0
#
#
# Operation: pool_3/_reshape/shape
# pool_3/_reshape/shape Output  pool_3/_reshape/shape:0
#
#
# Operation: pool_3/_reshape
# pool_3/_reshape Input  pool_3:0 TensorShape([Dimension(1), Dimension(1), Dimension(1), Dimension(2048)])
# pool_3/_reshape Input  pool_3/_reshape/shape:0 TensorShape([Dimension(2)])
# pool_3/_reshape Output  pool_3/_reshape:0
#
#
# Operation: softmax/weights
# softmax/weights Output  softmax/weights:0
#
#
# Operation: softmax/biases
# softmax/biases Output  softmax/biases:0
#
#
# Operation: softmax/logits/MatMul
# softmax/logits/MatMul Input  pool_3/_reshape:0 TensorShape([Dimension(1), Dimension(2048)])
# softmax/logits/MatMul Input  softmax/weights:0 TensorShape([Dimension(2048), Dimension(1008)])
# softmax/logits/MatMul Output  softmax/logits/MatMul:0
#
#
# Operation: softmax/logits
# softmax/logits Input  softmax/logits/MatMul:0 TensorShape([Dimension(1), Dimension(1008)])
# softmax/logits Input  softmax/biases:0 TensorShape([Dimension(1008)])
# softmax/logits Output  softmax/logits:0
#
#
# Operation: softmax
# softmax Input  softmax/logits:0 TensorShape([Dimension(1), Dimension(1008)])
# softmax Output  softmax:0
